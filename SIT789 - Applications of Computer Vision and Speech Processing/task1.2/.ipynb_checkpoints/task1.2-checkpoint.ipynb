# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt 
import math

img2 = cv.imread('img2.jpg')
img3 = cv.imread('img3.jpg')

# %%
def color_hist(img):
    hist_blue = cv.calcHist([img],[0],None,[256],[0,256]) #[0] for the blue channel 
    hist_green = cv.calcHist([img],[1],None,[256],[0,256]) #[0] for the blue channel 
    hist_red = cv.calcHist([img],[2],None,[256],[0,256]) #[0] for the blue channel 
    
    plt.plot(hist_blue, color = 'b') 
    plt.xlim([0,256]) 
    plt.show()
    
    plt.plot(hist_green, color = 'g') 
    plt.xlim([0,256]) 
    plt.show()
    
    plt.plot(hist_red, color = 'r') 
    plt.xlim([0,256]) 
    plt.show()

# %%
color_hist(img2)

# %%
color_hist(img3)

# %%
img_gray2 = cv.cvtColor(img2, cv.COLOR_BGR2GRAY) 

hist_gray2 = cv.calcHist([img_gray2],[0],None,[256],[0,256]) 
plt.plot(hist_gray2) 
plt.xlim([0,256]) 
plt.show()

# %%
img_gray3 = cv.cvtColor(img3, cv.COLOR_BGR2GRAY) 

hist_gray3 = cv.calcHist([img_gray3],[0],None,[256],[0,256]) 
plt.plot(hist_gray3) 
plt.xlim([0,256]) 
plt.show()

# %%
def getCumulativeDis(hist): 
    c = [] #cummulative distribution 
    s = 0 
    for i in range(0, len(hist)): 
        s = s + hist[i] 
        c.append(s) 
    return c

# %%
c = getCumulativeDis(hist_gray2) 
plt.plot(c, label = 'cummulative distribution img 2', color = 'r') 
plt.legend(loc="upper left") 
plt.xlim([0,256]) 
plt.show()

# %%
c = getCumulativeDis(hist_gray3) 
plt.plot(c, label = 'cummulative distribution img 3', color = 'r') 
plt.legend(loc="upper left") 
plt.xlim([0,256]) 
plt.show()

# %%
img_equ2 = cv.equalizeHist(img_gray2) 
plt.imshow(img_equ2, cmap='gray')

# %%
img_equ3 = cv.equalizeHist(img_gray3) 
plt.imshow(img_equ3, cmap='gray')

# %%
hist_equ2 = cv.calcHist([img_equ2],[0],None,[256],[0,256]) 
plt.plot(hist_equ2) 
plt.xlim([0,256]) 
plt.show()

# %%
hist_equ3 = cv.calcHist([img_equ3],[0],None,[256],[0,256]) 
plt.plot(hist_equ3) 
plt.xlim([0,256]) 
plt.show()

# %%
c_equ2 = getCumulativeDis(hist_equ2) 
plt.plot(c_equ,label='cummulative distribution after histogram equalisation of img 2',color='r') 
plt.legend(loc="upper left") 
plt.xlim([0,256]) 
plt.show()

# %%
c_equ3 = getCumulativeDis(hist_equ3) 
plt.plot(c_equ,label='cummulative distribution after histogram equalisation of img 3',color='r') 
plt.legend(loc="upper left") 
plt.xlim([0,256]) 
plt.show()

# %%
def Chi_2(H1, H2):
    h1 = H1 + 1e-10
    h2 = H2 + 1e-10
    
    num = (h1-h2) ** 2
    denorm = (h1 + h2)
    return np.sum(num / denorm)

# %%
def kl_divergence(H1, H2):
    h1 = H1 + 1e-10
    h2 = H2 + 1e-10
    
    s1 = np.sum(h1)
    s2 = np.sum(h2)
    h1 /= s1
    h2 /= s2
    
    log = [math.log(y) for y in (h1/h2)]
    kl = h1 * log
    return np.sum(kl)

# %%
Chi_2_hist2 = Chi_2(hist_gray2, hist_equ2)
print(Chi_2_hist2)
# Out:
# 1806031.2

# %%
kl_divergence_hist2 = kl_divergence(hist_gray2, hist_equ2)
print(kl_divergence_hist2)
# Out:
# 2754.872556770552
# C:\Users\micha\AppData\Local\Temp\ipykernel_17472\4239048301.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   log = [math.log(y) for y in (h1/h2)]

# %%
Chi_2_hist3 = Chi_2(hist_gray3, hist_equ3)
print(Chi_2_hist3)
# Out:
# 97802.65

# %%
kl_divergence_hist3 = kl_divergence(hist_gray3, hist_equ3)
print(kl_divergence_hist3)
# Out:
# 2780.194770783947
# C:\Users\micha\AppData\Local\Temp\ipykernel_17472\4239048301.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   log = [math.log(y) for y in (h1/h2)]
