# %%
import cv2 as cv 
 
def detect_face(image, cascade_detector, scaleFactor, minNeighbors, minSize): 
    #convert input image to grayscale 
    image_gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY) 
     
    faces = cascade_detector.detectMultiScale(image_gray, 
            scaleFactor = scaleFactor, #the ratio between two consecutive scales, must be > 1 
            minNeighbors = minNeighbors, #minimum number of overlapping windows to be considered  
            minSize = minSize) #minimum size of a detection window (in pixels) 
     
    return faces

# %%
import time 
 
input_image = cv.imread('FaceImages/abba.png') 
cascade_detector = cv.CascadeClassifier('haarcascade_frontalface_default.xml') 
 
start_time = time.time() 
faces = detect_face(input_image, cascade_detector, 1.1, 5, (30, 30)) 
print('Face detection is performed in %s seconds ---' % (time.time() - start_time))
# Out:
# Face detection is performed in 0.19197773933410645 seconds ---

# %%
if (faces is not None): 
    print('Found ', len(faces), ' faces') 
else: 
    print('There is no face found!')
# Out:
# Found  4  faces

# %%
from matplotlib import pyplot as plt 
 
output_image = input_image.copy() 
for (x, y, w, h) in faces: #(x, y) are the coordinates of the topleft corner,  
       #w and h are the width and height of the bounding box 
    cv.rectangle(output_image, (x, y), (x + w, y + h), (0, 255, 0), 2) 
     
plt.imshow(output_image[:,:,::-1]) # RGB-> BGR

# %%
start_time = time.time() 
faces = detect_face(input_image, cascade_detector, 1.5, 5, (30, 30)) 
print('Face detection is performed in %s seconds ---' % (time.time() - start_time)) 

output_image = input_image.copy() 
for (x, y, w, h) in faces: #(x, y) are the coordinates of the topleft corner,  
       #w and h are the width and height of the bounding box 
    cv.rectangle(output_image, (x, y), (x + w, y + h), (0, 255, 0), 2) 
     
plt.imshow(output_image[:,:,::-1]) # RGB-> BGR
# Out:
# Face detection is performed in 0.020003080368041992 seconds ---

# %%
start_time = time.time() 
faces = detect_face(input_image, cascade_detector, 2.0, 5, (30, 30)) 
print('Face detection is performed in %s seconds ---' % (time.time() - start_time)) 

output_image = input_image.copy() 
for (x, y, w, h) in faces: #(x, y) are the coordinates of the topleft corner,  
       #w and h are the width and height of the bounding box 
    cv.rectangle(output_image, (x, y), (x + w, y + h), (0, 255, 0), 2) 
     
plt.imshow(output_image[:,:,::-1]) # RGB-> BGR
# Out:
# Face detection is performed in 0.03545022010803223 seconds ---

# %%
start_time = time.time() 
faces = detect_face(input_image, cascade_detector, 1.1, 0, (30, 30)) 
print('Face detection is performed in %s seconds ---' % (time.time() - start_time)) 

output_image = input_image.copy() 
for (x, y, w, h) in faces: #(x, y) are the coordinates of the topleft corner,  
       #w and h are the width and height of the bounding box 
    cv.rectangle(output_image, (x, y), (x + w, y + h), (0, 255, 0), 2) 
     
plt.imshow(output_image[:,:,::-1]) # RGB-> BGR
# Out:
# Face detection is performed in 0.17852091789245605 seconds ---

# %%
start_time = time.time() 
faces = detect_face(input_image, cascade_detector, 1.1, 5, (30, 30)) 
print('Face detection is performed in %s seconds ---' % (time.time() - start_time)) 

output_image = input_image.copy() 
for (x, y, w, h) in faces: #(x, y) are the coordinates of the topleft corner,  
       #w and h are the width and height of the bounding box 
    cv.rectangle(output_image, (x, y), (x + w, y + h), (0, 255, 0), 2) 
     
plt.imshow(output_image[:,:,::-1]) # RGB-> BGR
# Out:
# Face detection is performed in 0.07021212577819824 seconds ---

# %%
start_time = time.time() 
faces = detect_face(input_image, cascade_detector, 1.1, 50, (30, 30)) 
print('Face detection is performed in %s seconds ---' % (time.time() - start_time)) 

output_image = input_image.copy() 
for (x, y, w, h) in faces: #(x, y) are the coordinates of the topleft corner,  
       #w and h are the width and height of the bounding box 
    cv.rectangle(output_image, (x, y), (x + w, y + h), (0, 255, 0), 2) 
     
plt.imshow(output_image[:,:,::-1]) # RGB-> BGR
# Out:
# Face detection is performed in 0.07567524909973145 seconds ---

# %%
start_time = time.time() 
faces = detect_face(input_image, cascade_detector, 1.1, 5, (10, 10)) 
print('Face detection is performed in %s seconds ---' % (time.time() - start_time)) 

output_image = input_image.copy() 
for (x, y, w, h) in faces: #(x, y) are the coordinates of the topleft corner,  
       #w and h are the width and height of the bounding box 
    cv.rectangle(output_image, (x, y), (x + w, y + h), (0, 255, 0), 2) 
     
plt.imshow(output_image[:,:,::-1]) # RGB-> BGR
# Out:
# Face detection is performed in 0.07681560516357422 seconds ---

# %%
start_time = time.time() 
faces = detect_face(input_image, cascade_detector, 1.1, 5, (30, 30)) 
print('Face detection is performed in %s seconds ---' % (time.time() - start_time)) 

output_image = input_image.copy() 
for (x, y, w, h) in faces: #(x, y) are the coordinates of the topleft corner,  
       #w and h are the width and height of the bounding box 
    cv.rectangle(output_image, (x, y), (x + w, y + h), (0, 255, 0), 2) 
     
plt.imshow(output_image[:,:,::-1]) # RGB-> BGR
# Out:
# Face detection is performed in 0.06595587730407715 seconds ---

# %%
start_time = time.time() 
faces = detect_face(input_image, cascade_detector, 1.1, 5, (100, 100)) 
print('Face detection is performed in %s seconds ---' % (time.time() - start_time)) 

output_image = input_image.copy() 
for (x, y, w, h) in faces: #(x, y) are the coordinates of the topleft corner,  
       #w and h are the width and height of the bounding box 
    cv.rectangle(output_image, (x, y), (x + w, y + h), (0, 255, 0), 2) 
     
plt.imshow(output_image[:,:,::-1]) # RGB-> BGR
# Out:
# Face detection is performed in 0.015561342239379883 seconds ---
